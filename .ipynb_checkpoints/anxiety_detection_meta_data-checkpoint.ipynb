# %%
import pandas as pd
import numpy as np
import os
import glob
from pathlib import Path
import numpy as np

# %%
meta_data_path = "/home/muhammad/Desktop/Datasets/dataset_anxiety/1_fusion_corpus_anxiety/meta_anxiety.xlsx"

# %%
meta_df_fusion = pd.read_excel(meta_data_path)

# %%
unique_bai_values_fusion = meta_df_fusion["BAITotal"].unique()

# %%
unique_bai_values_fusion
# Out:
# array([ 4.,  9.,  0., 20.,  2., 10., 14., 17., 11.,  1.,  8., 19.,  6.,
#         5.,  3., 26., 18.,  7., 37., 16., 43., 24., 12., 15., 13., 27.,
#        51., 21., 31., 28., 23., 47., 40., 33., nan, 39., 32., 25., 44.,
#        30., 29., 34., 35., 22., 36., 38., 60., 49., 41.])

# %%
meta_df_fusion["BAITotal"].nunique()
# Out:
# 48

# %%
bai_score_fusion = meta_df_fusion["BAITotal"].values

# %%
# variable to hold the count

# %%
distinct_value_count_fusion = {}

for single_score in bai_score_fusion:
    
    if distinct_value_count_fusion.get(single_score):
        
        distinct_value_count_fusion[single_score] = distinct_value_count_fusion[single_score] + 1
        
    else:
        
        distinct_value_count_fusion[single_score] = 1

# %%
distinct_value_count_fusion
# Out:
# {4.0: 802,
#  9.0: 557,
#  0.0: 1021,
#  20.0: 184,
#  2.0: 545,
#  10.0: 342,
#  14.0: 263,
#  17.0: 112,
#  11.0: 310,
#  1.0: 545,
#  8.0: 490,
#  19.0: 111,
#  6.0: 537,
#  5.0: 484,
#  3.0: 465,
#  26.0: 134,
#  18.0: 139,
#  7.0: 586,
#  37.0: 23,
#  16.0: 366,
#  43.0: 12,
#  24.0: 100,
#  12.0: 434,
#  15.0: 193,
#  13.0: 187,
#  27.0: 25,
#  51.0: 7,
#  21.0: 160,
#  31.0: 56,
#  28.0: 43,
#  23.0: 72,
#  47.0: 15,
#  40.0: 51,
#  33.0: 83,
#  nan: 1,
#  nan: 1,
#  nan: 1,
#  nan: 1,
#  nan: 1,
#  nan: 1,
#  nan: 1,
#  nan: 1,
#  nan: 1,
#  39.0: 27,
#  32.0: 44,
#  25.0: 65,
#  44.0: 25,
#  30.0: 18,
#  29.0: 31,
#  34.0: 44,
#  35.0: 20,
#  22.0: 101,
#  36.0: 14,
#  38.0: 78,
#  60.0: 8,
#  49.0: 8,
#  41.0: 19,
#  nan: 1,
#  nan: 1}

# %%
meta_data_anxiety_bai ="/home/muhammad/Desktop/Datasets/dataset_anxiety/1_Metadata_Anxiety_BAI_Checked/Metadaten_Anxiety_BAI_checked1.xlsx"

# %%
meta_data = pd.read_excel(meta_data_anxiety_bai)

# %%
unique_bai_values = meta_data["BAITotal"].unique()

# %%
unique_bai_values
# Out:
# array([ 4.,  9.,  0., 20.,  2., 10., 14., 17., 11.,  1.,  8., 19.,  6.,
#         5.,  3., 26., 18.,  7., 37., 16., 43., 24., 12., 15., 13., 27.,
#        51., 21., 31., 28., 23., 47., 40., 33., nan, 39., 32., 25., 44.,
#        30., 29., 34., 35., 22., 36., 38., 60., 49., 41.])

# %%
meta_data["BAITotal"].nunique()
# Out:
# 48

# %%
bai_total = meta_data["BAITotal"].values

# %%
bai_total
# Out:
# array([ 4.,  4.,  4., ..., 11., 11., 11.])

# %%
distinct_value_count = {}

for single_score in bai_total:
    
    if distinct_value_count.get(single_score):
        
        distinct_value_count[single_score] = distinct_value_count[single_score] + 1
        
    else:
        
        distinct_value_count[single_score] = 1

# %%
distinct_value_count
# Out:
# {4.0: 882,
#  9.0: 604,
#  0.0: 1098,
#  20.0: 207,
#  2.0: 595,
#  10.0: 378,
#  14.0: 287,
#  17.0: 129,
#  11.0: 336,
#  1.0: 572,
#  8.0: 529,
#  19.0: 121,
#  6.0: 587,
#  5.0: 518,
#  3.0: 505,
#  26.0: 148,
#  18.0: 158,
#  7.0: 638,
#  37.0: 28,
#  16.0: 378,
#  43.0: 16,
#  24.0: 109,
#  12.0: 464,
#  15.0: 211,
#  13.0: 207,
#  27.0: 32,
#  51.0: 8,
#  21.0: 164,
#  31.0: 60,
#  28.0: 45,
#  23.0: 83,
#  47.0: 16,
#  40.0: 53,
#  33.0: 89,
#  nan: 1,
#  nan: 1,
#  nan: 1,
#  nan: 1,
#  nan: 1,
#  nan: 1,
#  nan: 1,
#  nan: 1,
#  nan: 1,
#  39.0: 28,
#  32.0: 47,
#  25.0: 70,
#  44.0: 25,
#  30.0: 20,
#  29.0: 32,
#  34.0: 47,
#  35.0: 20,
#  22.0: 104,
#  36.0: 15,
#  38.0: 78,
#  60.0: 8,
#  49.0: 8,
#  41.0: 21,
#  nan: 1,
#  nan: 1}

# %%
file_names = meta_data["Filename"].values

# %%
file_names.size
# Out:
# 10789

# %%
file_names_fusion = meta_df_fusion["Filename_global"].values

# %%
file_names_fusion.size
# Out:
# 9967

# %%
file_names_fusion_set = set(file_names_fusion)
file_names_set=set(file_names)

# %%
result_differrence = list(set(file_names_fusion_set).symmetric_difference(set(file_names_set)))

# %%
len(result_differrence)
# Out:
# 20747

# %%
file_names_fusion_set.intersection(file_names_set)
# Out:
# {'535_bear',
#  '200_rd_butter',
#  '494_tat_cookie',
#  '535_embassy',
#  '562_sg_sahne',
#  '392_tat_ladies',
#  '169_story_food_childhood',
#  '538_lobster',
#  '487_sg_guten_abend',
#  '406_tat_nanny',
#  '567_a_smile',
#  '276_tat_boat',
#  '333_tat_ladies',
#  '401_directions',
#  '515_friesen',
#  '525_reststop',
#  '580_rd_butter_2',
#  '546_fridge',
#  '532_rd_butter',
#  '069_ocean',
#  '539_coffee',
#  '067_phone_call',
#  '438_tat_cry',
#  '223_tat_boy',
#  '178_a_comf',
#  '226_rd_butter',
#  '491_sg_guten_abend',
#  '467_traffic',
#  '054_a_comf',
#  '246_story_food_childhood',
#  '377_rd_rainbow2_2_3',
#  '376_rd_faber',
#  '329_tat_ladies',
#  '138_rd_northw',
#  '517_juliet',
#  '574_counting',
#  '193_story_food_childhood',
#  '397_rd_faber',
#  '200_ID',
#  '538_sea',
#  '557_present_2',
#  '257_story_food_childhood',
#  '053_counting',
#  '058_ID',
#  '572_a_smile',
#  '475_tat_cookie',
#  '525_sg_guten_abend',
#  '054_tat_ladies',
#  '100_story_best_vacation',
#  '209_tat_cry',
#  '530_a_smile',
#  '465_counting',
#  '333_tat_cem',
#  '524_lobster',
#  '483_rd_northw',
#  '187_ocean',
#  '359_tat_couple',
#  '526_bear',
#  '538_openoffice',
#  '330_tat_gnome',
#  '480_counting',
#  '543_crosseyed',
#  '555_counting',
#  '521_deadgirl',
#  '326_rd_rainbow2',
#  '526_rabbit',
#  '551_rd_northw',
#  '287_tat_men',
#  '526_pixar',
#  '527_present',
#  '250_counting',
#  '283_counting',
#  '323_sg_sahne',
#  '125_story_best_vacation',
#  '540_hopp',
#  '377_tat_cookie',
#  '207_ID',
#  '021_a_power',
#  '447_rd_northw',
#  '050_tat_boy',
#  '372_rd_northw_2_3',
#  '580_a_comf',
#  '500_counting',
#  '320_rd_northw_2',
#  '442_rd_rainbow2',
#  '471_rd_northw',
#  '569_present',
#  '062_tat_boy',
#  '535_snake',
#  '385_tat_nanny_2',
#  '430_tat_cookie',
#  '546_cup',
#  '412_rd_rainbow',
#  '536_casting',
#  '519_granddad',
#  '251_rd_butter_2',
#  '164_tat_cry',
#  '381_tat_couple',
#  '557_rd_northw_2',
#  '562_rd_northw_2',
#  '131_story_best_vacation',
#  '327_tat_cem',
#  '515_flight',
#  '045_ID',
#  '240_counting',
#  '297_tat_cookie',
#  '417_tat_woman',
#  '510_clown',
#  '534_present',
#  '579_rd_faber',
#  '523_hopp',
#  '545_story_disgust_childhood',
#  '187_tat_cookie',
#  '274_counting',
#  '531_window',
#  '060_a_comf',
#  '510_a_power',
#  '556_a_smile_2',
#  '374_rd_northw',
#  '545_counting',
#  '479_rd_northw',
#  '270_tat_cookie',
#  '547_a_comf',
#  '240_sg_sahne',
#  '521_frontdoor',
#  '396_rd_northw',
#  '549_gangrene',
#  '409_counting',
#  '550_air_cess',
#  '563_rd_faber',
#  '334_tat_cry_2',
#  '541_clown',
#  '523_rd_butter',
#  '554_rd_northw',
#  '307_tat_cookie',
#  '433_rd_rainbow2',
#  '057_a_power',
#  '525_toilet',
#  '374_directions',
#  '582_ocean',
#  '552_a_smile',
#  '469_air_nov',
#  '305_counting',
#  '241_a_comf',
#  '274_rd_butter',
#  '520_lego',
#  '017_tat_cookie',
#  '092_tat_cry',
#  '188_ID',
#  '383_rd_faber',
#  '445_air_nov',
#  '574_story_disgust_childhood_2',
#  '298_dish',
#  '345_rd_faber_2_3',
#  '406_rd_rainbow',
#  '511_number',
#  '255_story_sad_childhood',
#  '491_story_sad_childhood',
#  '330_tat_cem_2',
#  '221_tat_boy',
#  '523_error',
#  '534_shark',
#  '182_rd_butter',
#  '386_counting',
#  '498_tat_cry',
#  '517_present',
#  '233_story_food_childhood',
#  '551_a_power',
#  '244_gdl',
#  '523_face',
#  '003_a_sad',
#  '463_rd_rainbow2',
#  '432_tat_boy',
#  '213_ID',
#  '339_rd_faber_2',
#  '186_tat_cookie',
#  '522_evening',
#  '585_present',
#  '232_a_power',
#  '281_tat_cry',
#  '542_baby',
#  '501_tat_ladies',
#  '164_a_sad',
#  '523_tv',
#  '474_rd_northw',
#  '578_story_disgust_childhood',
#  '543_window',
#  '278_a_sad',
#  '067_a_sad',
#  '504_tat_cry',
#  '525_casting',
#  '568_rd_butter',
#  '444_error',
#  '426_rd_northw_2_3',
#  '543_rd_rainbow',
#  '579_a_smile',
#  '332_tat_ladies',
#  '558_sg_guten_abend',
#  '445_hamburg',
#  '517_reststop',
#  '253_story_food_childhood',
#  '236_story_sad_childhood',
#  '220_a_comf',
#  '570_ocean',
#  '530_sea',
#  '522_pigeon',
#  '230_phone_call',
#  '381_tat_ladies',
#  '461_counting',
#  '063_tat_ladies',
#  '299_dish',
#  '542_vpnr',
#  '340_rd_rainbow2',
#  '524_laundry',
#  '553_sg_guten_abend',
#  '556_sg_guten_abend_2',
#  '512_hopp',
#  '501_tat_cry',
#  '215_ID',
#  '015_tat_boy',
#  '422_tat_boy',
#  '545_crosseyed',
#  '186_story_food_childhood',
#  '149_tat_cry',
#  '547_emergency',
#  '286_tat_boat',
#  '338_directions_2_3',
#  '369_rd_northw_2_3',
#  '549_ocean_2',
#  '575_story_disgust_childhood_2',
#  '130_rd_northw',
#  '512_rabbit',
#  '171_tat_cookie',
#  '429_rd_faber',
#  '544_sg_sahne',
#  '428_tat_woman',
#  '062_tat_cry',
#  '051_a_power',
#  '052_ocean',
#  '214_counting',
#  '273_rd_butter',
#  '206_counting',
#  '462_number',
#  '539_embassy',
#  '291_story_sad_childhood',
#  '548_story_disgust_childhood',
#  '537_a_power',
#  '455_tat_ladies',
#  '433_counting_2',
#  '436_tat_couple',
#  '541_ocean',
#  '219_rd_butter',
#  '539_chair',
#  '541_newfriend',
#  '528_granddad',
#  '359_tat_nanny',
#  '023_tat_ladies',
#  '487_rd_northw',
#  '582_a_comf',
#  '023_story_best_vacation',
#  '462_friesen_2',
#  '269_story_sad_childhood',
#  '227_story_sad_childhood',
#  '542_dry',
#  '547_rd_northw',
#  '556_a_sad_2',
#  '569_gangrene_2',
#  '243_sg_geile_zeit',
#  '355_counting',
#  '578_rd_faber_2',
#  '127_gdl',
#  '510_rabbit',
#  '238_a_sad',
#  '010_a_comf',
#  '309_tat_ladies',
#  '534_newfriend',
#  '549_dry',
#  '319_room',
#  '535_crosseyed',
#  '578_sg_guten_abend_2',
#  '063_ID',
#  '303_present',
#  '215_a_comf',
#  '470_friesen',
#  '337_present',
#  '542_a_sad',
#  '512_sg_sahne',
#  '485_tat_cry',
#  '517_gmx',
#  '581_a_sad',
#  '167_story_sad_childhood',
#  '405_rd_rainbow2',
#  '450_error',
#  '519_roger',
#  '258_tat_boy',
#  '537_sea',
#  '275_story_sad_childhood',
#  '344_rd_northw_2_3',
#  '051_story_food_childhood',
#  '503_desert',
#  '533_chair',
#  '562_counting_2',
#  '512_wusel',
#  '088_story_best_vacation',
#  '534_counting',
#  '038_story_sad_childhood',
#  '310_tat_ladies',
#  '543_embassy',
#  '269_tat_men',
#  '524_sg_sahne',
#  '571_a_power',
#  '512_dish',
#  '051_rd_butter',
#  '537_afrik',
#  '536_face',
#  '023_rd_butter',
#  '193_a_sad',
#  '024_phone_call',
#  '041_ocean',
#  '510_laundry',
#  '302_present',
#  '312_rd_faber',
#  '269_a_comf',
#  '537_lobster',
#  '040_story_food_childhood',
#  '059_story_best_vacation',
#  '377_tat_ladies',
#  '051_story_sad_childhood',
#  '578_rd_zeh',
#  '179_counting',
#  '559_sg_sahne_2',
#  '517_afrik',
#  '250_gdl',
#  '251_story_best_vacation',
#  '550_sg_sahne_2',
#  '423_rd_faber',
#  '273_story_sad_childhood',
#  '544_story_sad_childhood',
#  '319_tat_couple',
#  '180_counting',
#  '306_directions_2_3',
#  '390_counting_2',
#  '044_ID',
#  '515_deadgirl',
#  '090_story_best_vacation',
#  '448_emergency',
#  '177_tat_cookie',
#  '535_rabbit',
#  '120_story_best_vacation',
#  '297_tat_cry',
#  '336_tat_boy',
#  '540_lct',
#  '514_face',
#  '283_tat_cookie',
#  '252_rd_butter_2',
#  '314_rd_rainbow2',
#  '519_coffee',
#  '072_rd_northw',
#  '250_tat_ladies',
#  '561_rd_zeh',
#  '354_tat_couple',
#  '021_tat_boy',
#  '113_gdl',
#  '519_traffic',
#  '510_window',
#  '525_lobster',
#  '426_dish',
#  '562_rd_faber2',
#  '569_rd_northw_2',
#  '088_gdl',
#  '003_ocean',
#  '566_ocean_2',
#  '583_story_disgust_childhood',
#  '042_rd_butter',
#  '290_tat_men',
#  '331_directions_2_3',
#  '575_face_2',
#  '535_tv',
#  '180_tat_cry',
#  '509_dry',
#  '008_rd_butter',
#  '538_a_power',
#  '514_laundry',
#  '516_hospice',
#  '011_a_power',
#  '518_clown',
#  '544_friesen',
#  '182_a_power',
#  '012_a_power',
#  '048_story_food_childhood',
#  '057_story_sad_childhood',
#  '524_a_sad',
#  '536_number',
#  '582_gangrene',
#  '335_rd_rainbow2',
#  '524_sg_guten_abend',
#  '417_rd_rainbow2',
#  '343_tat_woman',
#  '528_number',
#  '535_granddad',
#  '412_tat_cry',
#  '404_tat_men',
#  '511_granddad',
#  '378_tat_boat',
#  '522_roger',
#  '525_baby',
#  '092_rd_northw',
#  '247_tat_cookie',
#  '575_rd_butter_2',
#  '043_rd_butter',
#  '545_friesen',
#  '121_tat_cry',
#  '471_tat_cookie',
#  '493_sg_guten_abend',
#  '165_a_power',
#  '376_tat_ladies',
#  '564_present',
#  '555_rd_zeh',
#  '569_face',
#  '332_present_2',
#  '555_story_disgust_childhood_2',
#  '538_sg_sahne',
#  '258_a_sad',
#  '516_hopp',
#  '559_rd_faber',
#  '498_present',
#  '362_dish',
#  '415_rd_northw_2',
#  '153_rd_northw',
#  '318_rd_faber_2',
#  '409_tat_men',
#  '340_tat_cookie',
#  '450_present',
#  '219_phone_call',
#  '041_a_comf',
#  '432_rd_faber_2',
#  '518_crosseyed',
#  '144_story_best_vacation',
#  '058_a_power',
#  '011_tat_ladies',
#  '252_tat_ladies',
#  '385_tat_cookie',
#  '240_tat_boy',
#  '280_tat_cookie',
#  '348_rd_rainbow',
#  '551_a_comf',
#  '577_cup',
#  '388_tat_couple',
#  '363_rd_faber',
#  '540_granddad',
#  '554_ocean',
#  '189_a_sad',
#  '081_gdl',
#  '569_ocean_2',
#  '257_rd_butter_2',
#  '534_evening',
#  '365_directions_2',
#  '575_sg_guten_abend_2',
#  '429_rd_rainbow2_2',
#  '414_tat_cry',
#  '319_rd_northw',
#  '304_directions',
#  '539_sea',
#  '519_cup',
#  '442_tat_cookie',
#  '116_gdl',
#  '254_rd_butter_1',
#  '218_tat_boy',
#  '545_lct',
#  '576_rd_northw_2',
#  '571_rd_butter',
#  '179_story_best_vacation',
#  '514_chair',
#  '389_tat_cookie',
#  '549_pinkflamingo',
#  '535_rd_rainbow',
#  '571_sg_sahne',
#  '174_tat_cookie',
#  '275_rd_butter',
#  '097_gdl',
#  '248_rd_butter_2',
#  '476_tat_ladies',
#  '013_ID',
#  '522_deadgirl',
#  '449_number',
#  '427_rd_rainbow2_2',
#  '334_tat_ladies_2',
#  '188_tat_cookie',
#  '575_a_smile_2',
#  '363_counting_2',
#  '517_openoffice',
#  '379_dish',
#  '541_pigeon',
#  '280_a_sad',
#  '389_rd_rainbow2',
#  '512_air_cess',
#  '534_sea',
#  '235_counting',
#  '231_tat_cookie',
#  '186_rd_butter',
#  '548_rd_rainbow_2',
#  '528_embassy',
#  '541_lego',
#  '034_phone_call',
#  '007_tat_boy',
#  '335_rd_northw_2_3',
#  '357_rd_faber',
#  '040_ID',
#  '281_counting',
#  '335_tat_couple',
#  '325_sg_sahne',
#  '283_chair',
#  '296_tat_ladies',
#  '266_a_power',
#  '533_rd_rainbow',
#  '024_ID',
#  '516_openoffice',
#  '219_tat_ladies',
#  '070_tat_cry',
#  '066_tat_boy',
#  '330_tat_cookie',
#  '511_bear',
#  '227_rd_butter',
#  '563_sg_sahne_2',
#  '378_counting_2',
#  '385_rd_northw_2',
#  '197_story_sad_childhood',
#  '257_sg_atemlos',
#  '052_counting',
#  '580_cup',
#  '200_tat_boy',
#  '432_tat_cookie',
#  '514_snake',
#  '394_tat_men_2',
#  '537_window',
#  '202_rd_butter',
#  '360_directions',
#  '531_frontdoor',
#  '558_ocean_2',
#  '361_rd_northw_2',
#  '261_tat_ladies',
#  '574_face_2',
#  '553_counting_2',
#  '331_counting_2',
#  '550_roger',
#  '544_roger',
#  '426_present',
#  '285_rd_butter',
#  '394_rd_northw',
#  '578_ocean_2',
#  '524_lego',
#  '208_story_sad_childhood',
#  '288_chair',
#  '493_tat_ladies',
#  '536_air_cess',
#  '227_tat_cry',
#  '516_bear',
#  '563_gangrene',
#  '509_traffic',
#  '554_rd_butter',
#  '407_tat_cry',
#  '547_roger',
#  '387_rd_faber_2',
#  '381_rd_northw_2',
#  '363_tat_nanny',
#  '451_tat_cry',
#  '322_counting',
#  '463_evening',
#  '190_story_best_vacation',
#  '192_ocean',
#  '285_tat_men',
#  '240_a_sad',
#  '427_tat_men',
#  '344_tat_couple',
#  '574_face',
#  '568_rd_butter_2',
#  '045_counting',
#  '311_counting',
#  '382_rd_faber_2',
#  '005_tat_ladies',
#  '233_tat_cry',
#  '509_hospice',
#  '259_tat_cry',
#  '440_tat_cookie',
#  '385_rd_rainbow',
#  '414_present',
#  '524_error',
#  '369_counting_2',
#  '483_tat_cookie',
#  '517_story_disgust_childhood',
#  '461_roger',
#  '468_tat_ladies',
#  '509_chair',
#  '533_afrik',
#  '039_a_comf',
#  '325_counting',
#  '515_emergency',
#  '101_story_best_vacation',
#  '177_story_sad_childhood',
#  '314_rd_northw_2_3',
#  '519_newfriend',
#  '524_study',
#  '532_a_power',
#  '540_joko',
#  '529_hospice',
#  '187_rd_butter',
#  '272_cup',
#  '575_a_sad_2',
#  '415_counting',
#  '580_sg_sahne_2',
#  '353_rd_northw',
#  '313_present',
#  '533_juliet',
#  '517_dry',
#  '571_ocean',
#  '190_counting',
#  '525_crosseyed',
#  '571_rd_zeh_2',
#  '311_rd_rainbow',
#  '335_rd_faber_2',
#  '462_dry',
#  '553_sg_guten_abend_2',
#  '562_ocean',
#  '196_tat_ladies',
#  '186_ID',
#  '301_rd_faber',
#  '315_directions',
#  '385_tat_men',
#  '468_air_cess',
#  '451_roger',
#  '435_tat_couple',
#  '530_lego',
#  '486_counting',
#  '540_lego',
#  '023_story_food_childhood',
#  '266_tat_boat',
#  '507_tat_ladies',
#  '063_tat_boy',
#  '528_face',
#  '221_story_sad_childhood',
#  '503_sg_guten_abend',
#  '573_story_disgust_childhood_2',
#  '205_phone_call',
#  '366_rd_rainbow2',
#  '253_gdl',
#  '248_story_sad_childhood',
#  '409_game',
#  '371_counting',
#  '513_pinkflamingo',
#  '514_ocean',
#  '310_tat_cry',
#  '522_rd_northw',
#  '210_rd_butter',
#  '515_pixar',
#  '308_directions_2',
#  '565_gangrene_2',
#  '530_toilet',
#  '379_directions',
#  '314_room_2',
#  '510_eel',
#  '261_tat_boy',
#  '295_tat_cookie',
#  '517_casting',
#  '332_tat_cem',
#  '522_eel',
#  '026_tat_cookie',
#  '413_tat_cry',
#  '055_tat_cry',
#  '530_rabbit',
#  '523_clown',
#  '282_story_best_vacation',
#  '527_flight',
#  '523_present',
#  '358_directions',
#  '545_pinkflamingo',
#  '576_ocean_2',
#  '263_story_sad_childhood',
#  '526_rd_rainbow',
#  '501_present',
#  '534_pigeon',
#  '523_dish',
#  '534_cup',
#  '245_story_food_childhood',
#  '468_rd_faber',
#  '523_evening',
#  '532_lobster',
#  '379_rd_northw_2',
#  '514_reststop',
#  '556_rd_butter_2',
#  '056_counting',
#  '381_counting',
#  '530_newfriend',
#  '530_snake',
#  '556_counting_2',
#  '544_error',
#  '166_a_comf',
#  '544_wusel',
#  '009_tat_boy',
#  '513_bear',
#  '036_story_food_childhood',
#  '402_tat_cry',
#  '004_counting',
#  '554_rd_faber',
#  '246_tat_cry',
#  '533_counting',
#  '422_game',
#  '551_a_sad',
#  '264_story_best_vacation',
#  '446_air_cnty',
#  '098_story_best_vacation',
#  '536_a_sad',
#  '558_ocean',
#  '422_rd_faber_2_3',
#  '544_rd_rainbow',
#  '293_dish',
#  '427_game',
#  '480_sg_guten_abend_2',
#  '061_tat_boy',
#  '538_pixar',
#  '577_ocean',
#  '208_a_sad',
#  '405_tat_boat',
#  '570_sg_sahne',
#  '566_story_disgust_childhood_2',
#  '186_story_best_vacation',
#  '344_rd_faber',
#  '507_counting',
#  '523_baby',
#  '526_dry',
#  '536_laundry',
#  '521_rd_rainbow',
#  '255_gdl',
#  '513_lego',
#  '498_rd_northw_2',
#  '334_rd_faber_2',
#  '521_lego',
#  '388_rd_rainbow2_2_3',
#  '540_air_cess',
#  '558_cup',
#  '511_clown',
#  '509_study',
#  '529_gmx',
#  '535_traffic',
#  '348_present',
#  '404_tat_cry',
#  '527_ocean',
#  '578_a_power_2',
#  '449_embassy',
#  '424_dish',
#  '524_counting',
#  '510_a_comf',
#  '456_tat_cry',
#  '056_story_sad_childhood',
#  '217_ocean',
#  '170_rd_butter',
#  '285_story_sad_childhood',
#  '434_tat_nanny',
#  '542_roger',
#  '242_tat_cry',
#  '289_a_sad',
#  '129_rd_northw',
#  '508_openoffice',
#  '318_tat_boy',
#  '408_rd_rainbow2',
#  '412_rd_faber_2',
#  '389_rd_faber_2',
#  '469_number',
#  '527_number',
#  '553_a_power',
#  '365_tat_boy',
#  '567_sg_sahne_2',
#  '176_tat_boy',
#  '225_tat_boy',
#  '485_tat_ladies',
#  '558_sg_sahne',
#  '584_rd_rainbow',
#  '382_rd_faber_2_3',
#  '346_tat_ladies',
#  '238_story_food_childhood',
#  '255_rd_butter_2',
#  '574_a_power',
#  '539_story_sad_childhood',
#  '515_finger',
#  '565_face',
#  '428_tat_ladies',
#  '109_tat_cry',
#  '384_tat_nanny',
#  '062_story_best_vacation',
#  '037_phone_call',
#  '464_rd_rainbow',
#  '531_chair',
#  '389_present',
#  '510_deadgirl',
#  '520_fridge',
#  '447_evening',
#  '208_tat_cookie',
#  '254_gdl',
#  '280_a_power',
#  '279_tat_men',
#  '281_tat_boat',
#  '537_joko',
#  '526_loveactually',
#  '497_tat_ladies',
#  '256_a_comf',
#  '509_flight',
#  '334_tat_cookie',
#  '562_rd_northw',
#  '300_rd_northw_2',
#  '545_a_power',
#  '578_sg_sahne_2',
#  '531_sea',
#  '144_tat_cry',
#  '123_story_best_vacation',
#  '203_tat_cookie',
#  '260_counting',
#  '580_ocean',
#  '342_tat_cry',
#  '529_chair',
#  '455_counting',
#  '567_a_smile_2',
#  '573_rd_rainbow',
#  '446_dry',
#  '541_loveactually',
#  '290_cup',
#  '534_laundry',
#  '331_tat_cem',
#  '299_tat_cookie',
#  '343_rd_faber_2',
#  '521_rd_butter',
#  '041_counting',
#  '332_tat_cookie',
#  '300_tat_woman',
#  '330_rd_northw',
#  '544_shark',
#  '370_directions',
#  '546_lct',
#  '281_tat_cookie',
#  '537_embassy',
#  '568_story_disgust_childhood_2',
#  '253_tat_ladies',
#  '057_story_best_vacation',
#  '505_present',
#  '497_story_sad_childhood',
#  '511_dish',
#  '198_story_food_childhood',
#  '130_tat_cry',
#  '546_hamburg',
#  '236_a_sad',
#  '289_tat_boat',
#  '173_story_best_vacation',
#  '331_rd_rainbow',
#  '544_deadgirl',
#  '549_sg_sahne_2',
#  '500_sg_guten_abend',
#  '087_tat_cry',
#  '516_toilet',
#  '538_dish',
#  '173_phone_call',
#  '519_loveactually',
#  '291_a_sad',
#  '522_a_power',
#  '367_tat_woman',
#  '204_tat_boy',
#  '548_sg_sahne',
#  '241_story_sad_childhood',
#  '536_traffic',
#  '029_counting',
#  '110_tat_cry',
#  '512_frontdoor',
#  '467_tat_cookie',
#  '534_lobster',
#  '509_eel',
#  '511_casting',
#  '214_story_sad_childhood',
#  '364_counting',
#  '494_rd_northw',
#  '223_tat_cookie',
#  '046_ocean',
#  '419_game',
#  '367_rd_faber_2',
#  '559_face',
#  '356_tat_cry',
#  '297_rd_faber_2',
#  '537_lego',
#  '339_tat_boat',
#  '425_counting',
#  '550_rd_faber_2',
#  '309_present',
#  '561_sg_guten_abend',
#  '585_ocean',
#  '560_rd_butter',
#  '127_tat_cry',
#  '100_gdl',
#  '106_gdl',
#  '525_window',
#  '082_story_best_vacation',
#  '560_rd_faber_2',
#  '511_joko',
#  '435_counting',
#  '546_reststop',
#  '497_desert',
#  '386_tat_ladies',
#  '226_counting',
#  '392_counting',
#  '483_counting',
#  '235_tat_ladies',
#  '565_rd_butter_2',
#  '256_sg_atemlos',
#  '335_tat_men',
#  '420_tat_men',
#  '521_window',
#  '441_tat_cry',
#  '525_rabbit',
#  '473_sg_sahne',
#  '436_rd_northw',
#  '511_crosseyed',
#  '152_tat_cry',
#  '002_story_food_childhood',
#  '245_a_power',
#  '490_counting',
#  '280_story_sad_childhood',
#  '516_snake',
#  '564_a_smile_2',
#  '252_counting',
#  '573_sg_sahne',
#  '543_sense',
#  '266_tat_cry',
#  '536_rd_butter',
#  '554_cup_2',
#  '402_rd_rainbow2_2_3',
#  '428_tat_cry',
#  '023_ocean',
#  '578_a_sad',
#  '224_tat_cry',
#  '542_cup',
#  '522_openoffice',
#  '288_a_power',
#  '061_phone_call',
#  '514_lego',
#  '525_juliet',
#  '204_ocean',
#  '286_chair',
#  '222_a_comf',
#  '532_emergency',
#  '542_fridge',
#  '210_tat_cookie',
#  '520_gmx',
#  '515_casting',
#  '554_ocean_2',
#  '514_study',
#  '197_counting',
#  '363_tat_ladies',
#  '056_story_food_childhood',
#  '268_story_sad_childhood',
#  '204_phone_call',
#  '528_wusel',
#  '186_phone_call',
#  '389_tat_nanny',
#  '550_present_2',
#  '509_face',
#  '110_story_best_vacation',
#  '257_sg_geile_zeit',
#  '564_story_disgust_childhood',
#  '569_rd_northw',
#  '477_rd_northw',
#  '464_friesen',
#  '538_gmx',
#  '349_tat_ladies',
#  '036_counting',
#  '367_rd_faber',
#  '531_casting',
#  '175_ID',
#  '558_cup_2',
#  '576_cup_2',
#  '559_a_comf',
#  '285_chair',
#  '213_phone_call',
#  '395_present',
#  '017_ID',
#  '115_gdl',
#  '169_tat_cry',
#  '017_story_sad_childhood',
#  '425_rd_northw_2',
#  '554_story_disgust_childhood',
#  '571_rd_faber',
#  '441_rd_northw',
#  '253_counting',
#  '556_sg_sahne',
#  '279_tat_cookie',
#  '431_tat_boat',
#  '550_rd_faber',
#  '014_rd_butter',
#  '537_flight',
#  '555_rd_rainbow',
#  '523_loveactually',
#  '532_evening',
#  '254_tat_cry',
#  '524_casting',
#  '200_a_power',
#  '544_newfriend',
#  ...}
